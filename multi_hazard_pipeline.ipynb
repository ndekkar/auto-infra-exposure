# %%
# ================================
#  Multi-Hazard Exposure Pipeline
#  Full Automatic Execution
# ================================

import sys
sys.path.append("utils")  # assuming hazards.py is under /utils/

from hazards import run_multi_hazard_pipeline

# -------------------------------
#  Launch the entire pipeline
# -------------------------------

run_multi_hazard_pipeline("config.yml")
# Out:
# --- Processing hazard: pluvial_flood ---
# --- Processing hazard: fluvial_flood ---
# Skipping hazard: landslide
# Skipping hazard: wildfire
#
# --- Processing combined flood ---
# Combined raster written to: output/combined_flood.tif
